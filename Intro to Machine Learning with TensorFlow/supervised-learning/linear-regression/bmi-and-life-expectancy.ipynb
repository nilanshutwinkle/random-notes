# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %config InlineBackend.close_figures = False

# %%
bmi_life_data = pd.read_csv('../../../data/bmi_and_life_expectancy.csv')
bmi_life_data
# Out:
#                 Country  Life expectancy       BMI
# 0           Afghanistan             52.8  20.62058
# 1               Albania             76.8  26.44657
# 2               Algeria             75.5  24.59620
# 3               Andorra             84.6  27.63048
# 4                Angola             56.7  22.25083
# ..                  ...              ...       ...
# 158             Vanuatu             63.4  26.78926
# 159  West Bank and Gaza             74.1  26.57750
# 160             Vietnam             74.1  20.91630
# 161              Zambia             51.1  20.68321
# 162            Zimbabwe             47.3  22.02660
#
# [163 rows x 3 columns]

# %% [markdown]
# Extract the labeled data:

# %%
X = bmi_life_data[['BMI']]
Y = bmi_life_data[['Life expectancy']]

# %%
plt.scatter(X, Y)
plt.show()

# %% [markdown]
# Fit a linear regression:

# %%
bmi_life_model = LinearRegression()
bmi_life_model.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
m = bmi_life_model.coef_[0][0]
b = bmi_life_model.intercept_[0]

"y = {:.2f}x + {:.2f}".format(m, b)
# Out:
# 'y = 2.52x + 7.23'

# %%
X_min = X.min()
X_max = X.max()
plt.plot([X_min, X_max],[m * X_min + b, m * X_max + b], 'g')
plt.show()

# %% [markdown]
# Use fitted model to predict a value:

# %%
laos_bmi = 21.07931
laos_life_exp = bmi_life_model.predict([ [laos_bmi] ])
laos_life_exp
# Out:
# array([[60.31564716]])

# %%
plt.plot(laos_bmi, laos_life_exp[0][0], 'r*', markersize=25)
plt.show()
